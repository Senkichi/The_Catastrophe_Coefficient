# %%
from sklearn import tree
import pandas as pd
import os

# %% [markdown]
#   ## Importing and cleaning the training dataset

# %%
data = pd.read_csv('../../Resources/bio_vars_frame.csv')
data.head()
# Out:
#    Unnamed: 0  bio_1  bio_2  bio_3   bio_4  bio_5  bio_6  bio_7  bio_8  bio_9  \
# 0           1   96.0  105.0   40.0  5390.0  250.0   -7.0  257.0   35.0  165.0
# 1           2   94.0  105.0   40.0  5385.0  249.0   -9.0  258.0   34.0  163.0
# 2           3   96.0  105.0   40.0  5407.0  251.0   -7.0  258.0   35.0  165.0
# 3           4   97.0  105.0   40.0  5437.0  251.0   -7.0  258.0   35.0  166.0
# 4           5   93.0  105.0   40.0  5438.0  248.0  -11.0  259.0   32.0  163.0
#
#        ...       bio_11  bio_12  bio_13  bio_14  bio_15  bio_16  bio_17  \
# 0      ...         30.0  2184.0   350.0    25.0    61.0  1008.0   144.0
# 1      ...         28.0  2196.0   354.0    24.0    62.0  1019.0   142.0
# 2      ...         30.0  2162.0   348.0    24.0    62.0  1002.0   140.0
# 3      ...         30.0  2144.0   345.0    24.0    62.0   993.0   139.0
# 4      ...         27.0  2188.0   357.0    24.0    63.0  1023.0   138.0
#
#    bio_18  bio_19  raster_frame
# 0   147.0   951.0             0
# 1   146.0   961.0             0
# 2   144.0   945.0             0
# 3   143.0   937.0             0
# 4   143.0   966.0             0
#
# [5 rows x 21 columns]

# %%
data.drop(['Unnamed: 0'], axis = 1, inplace = True)
data.dropna(axis = 0, how = 'any', inplace = True)
data.rename(columns={'bio_1': 'Annual Mean Temperature', 
                     'bio_2': 'Mean Diurnal Range (Mean of monthly (max temp - min temp))',
                     'bio_3': 'Isothermality',
                     'bio_4': 'Temperature Seasonality',
                     'bio_5': 'Max Temperature of Warmest Month',
                     'bio_6': 'Min Temperature of Coldest Month',
                     'bio_7': 'Temperature Annual Range',
                     'bio_8': 'Mean Temperature of Wettest Quarter',
                     'bio_9': 'Mean Temperature of Driest Quarter',
                     'bio_10': 'Mean Temperature of Warmest Quarter',
                     'bio_11': 'Mean Temperature of Coldest Quarter',
                     'bio_12': 'Annual Precipitation',
                     'bio_13': 'Precipitation of Wettest Month',
                     'bio_14': 'Precipitation of Driest Month',
                     'bio_15': 'Precipitation Seasonality (Coefficient of Variation)',
                     'bio_16': 'Precipitation of Wettest Quarter',
                     'bio_17': 'Precipitation of Driest Quarter',
                     'bio_18': 'Precipitation of Warmest Quarter',
                     'bio_19': 'Precipitation of Coldest Quarter',
                    }, inplace=True)

data = data[['raster_frame','Precipitation of Driest Month', 'Temperature Seasonality', 'Precipitation of Driest Quarter',
             'Annual Precipitation', 'Precipitation of Warmest Quarter']]

data.head()

# %% [markdown]
# ## Preprocessing the data for model training

# %%
target = data['raster_frame']
target_names = ["negative", "positive"]

# %%
X = data.drop(["raster_frame"], axis=1)
feature_names = X.columns
X.head()
# Out:
#    Precipitation of Driest Month  Temperature Seasonality  \
# 0                           25.0                   5390.0
# 1                           24.0                   5385.0
# 2                           24.0                   5407.0
# 3                           24.0                   5437.0
# 4                           24.0                   5438.0
#
#    Precipitation of Driest Quarter  Annual Precipitation  \
# 0                            144.0                2184.0
# 1                            142.0                2196.0
# 2                            140.0                2162.0
# 3                            139.0                2144.0
# 4                            138.0                2188.0
#
#    Precipitation of Warmest Quarter
# 0                             147.0
# 1                             146.0
# 2                             144.0
# 3                             143.0
# 4                             143.0

# %%
# Splitting up the data for training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, target, random_state=42)

# %%
# Testing accuracy on training and testing data
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)

# %% [markdown]
# ## Making a prediction on test data set

# %%
# Making prediction based on test data
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf = rf.fit(X_train, y_train)
prediction = rf.predict_proba(X_test)
print(prediction)
# Out:
# [[1.   0.  ]
#  [0.58 0.42]
#  [1.   0.  ]
#  ...
#  [1.   0.  ]
#  [1.   0.  ]
#  [1.   0.  ]]

# %%
# Looking at important of each feature
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.40939007993657767, 'Temperature Seasonality'),
#  (0.27623199779648944, 'Annual Precipitation'),
#  (0.14160813538841294, 'Precipitation of Warmest Quarter'),
#  (0.10417259395132726, 'Precipitation of Driest Quarter'),
#  (0.06859719292719256, 'Precipitation of Driest Month')]

# %% [markdown]
# ## Importing and cleaning new data set

# %%
harsh_2050 = pd.read_csv('../../Resources/2050_harsh.csv')

# %%
harsh_2050.drop(['Unnamed: 0'], axis = 1, inplace = True)
harsh_2050.dropna(axis = 0, how = 'any', inplace = True)
harsh_2050.rename(columns={'bc85bi501': 'Annual Mean Temperature', 
                     'bc85bi5010': 'Mean Temperature of Warmest Quarter',
                     'bc85bi5011': 'Mean Temperature of Coldest Quarter',
                     'bc85bi5012': 'Annual Precipitation',
                     'bc85bi5013': 'Precipitation of Wettest Month',
                     'bc85bi5014': 'Precipitation of Driest Month',
                     'bc85bi5015': 'Precipitation Seasonality (Coefficient of Variation)',
                     'bc85bi5016': 'Precipitation of Wettest Quarter',
                     'bc85bi5017': 'Precipitation of Driest Quarter',
                     'bc85bi5018': 'Precipitation of Warmest Quarter',
                     'bc85bi5019': 'Precipitation of Coldest Quarter',
                     'bc85bi502': 'Mean Diurnal Range (Mean of monthly (max temp - min temp))',
                     'bc85bi503': 'Isothermality',
                     'bc85bi504': 'Temperature Seasonality',
                     'bc85bi505': 'Max Temperature of Warmest Month',
                     'bc85bi506': 'Min Temperature of Coldest Month',
                     'bc85bi507': 'Temperature Annual Range',
                     'bc85bi508': 'Mean Temperature of Wettest Quarter',
                     'bc85bi509': 'Mean Temperature of Driest Quarter',
                    }, inplace=True)


harsh_2050.head()
# Out:
#             x        y  Annual Mean Temperature  \
# 0 -124.779167  49.3375                      109
# 1 -124.770833  49.3375                      106
# 2 -124.762500  49.3375                      104
# 3 -124.754167  49.3375                      111
# 4 -124.745833  49.3375                      119
#
#    Mean Temperature of Warmest Quarter  Mean Temperature of Coldest Quarter  \
# 0                                  182                                   48
# 1                                  177                                   47
# 2                                  176                                   45
# 3                                  184                                   50
# 4                                  193                                   54
#
#    Annual Precipitation  Precipitation of Wettest Month  \
# 0                  1925                             361
# 1                  1944                             363
# 2                  1950                             365
# 3                  1893                             354
# 4                  1849                             346
#
#    Precipitation of Driest Month  \
# 0                             29
# 1                             29
# 2                             30
# 3                             28
# 4                             25
#
#    Precipitation Seasonality (Coefficient of Variation)  \
# 0                                                 67
# 1                                                 67
# 2                                                 67
# 3                                                 68
# 4                                                 69
#
#    Precipitation of Wettest Quarter                 ...                  \
# 0                               916                 ...
# 1                               923                 ...
# 2                               924                 ...
# 3                               902                 ...
# 4                               887                 ...
#
#    Precipitation of Warmest Quarter  Precipitation of Coldest Quarter  \
# 0                               145                               839
# 1                               148                               690
# 2                               150                               691
# 3                               141                               825
# 4                               132                               812
#
#    Mean Diurnal Range (Mean of monthly (max temp - min temp))  Isothermality  \
# 0                                                 87                      35
# 1                                                 86                      35
# 2                                                 86                      35
# 3                                                 87                      35
# 4                                                 90                      35
#
#    Temperature Seasonality  Max Temperature of Warmest Month  \
# 0                     5383                               259
# 1                     5286                               253
# 2                     5296                               251
# 3                     5390                               262
# 4                     5524                               274
#
#    Min Temperature of Coldest Month  Temperature Annual Range  \
# 0                                12                       247
# 1                                10                       243
# 2                                 8                       243
# 3                                14                       248
# 4                                20                       254
#
#    Mean Temperature of Wettest Quarter  Mean Temperature of Driest Quarter
# 0                                   56                                 181
# 1                                   54                                 176
# 2                                   53                                 175
# 3                                   58                                 184
# 4                                   63                                 192
#
# [5 rows x 21 columns]

# %%
x_new = harsh_2050[['Precipitation of Driest Month', 'Temperature Seasonality', 'Precipitation of Driest Quarter',
             'Annual Precipitation', 'Precipitation of Warmest Quarter']]
x_new.head()
# Out:
#    Precipitation of Driest Month  Temperature Seasonality  \
# 0                             29                     5383
# 1                             29                     5286
# 2                             30                     5296
# 3                             28                     5390
# 4                             25                     5524
#
#    Precipitation of Driest Quarter  Annual Precipitation  \
# 0                              122                  1925
# 1                              125                  1944
# 2                              128                  1950
# 3                              119                  1893
# 4                              109                  1849
#
#    Precipitation of Warmest Quarter
# 0                               145
# 1                               148
# 2                               150
# 3                               141
# 4                               132

# %% [markdown]
# ## Making a prediction on our new data

# %%
harsh2050_prediction = rf.predict_proba(x_new)

# %% [markdown]
# ## Creating final dataframe and exporting

# %%
harsh2050_final = harsh_2050[['x', 'y']]
harsh2050_final["Prediction"] = harsh2050_prediction[:,1]
harsh2050_final.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             x        y  Prediction
# 0 -124.779167  49.3375         0.0
# 1 -124.770833  49.3375         0.0
# 2 -124.762500  49.3375         0.0
# 3 -124.754167  49.3375         0.0
# 4 -124.745833  49.3375         0.0

# %%
harsh2050_final.to_csv('2050_harsh_final.csv')
